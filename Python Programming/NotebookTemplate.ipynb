# %% [markdown]
# # Programming and Problem Solving
# ### Day No -
# ### Date -

# %% [markdown]
# # Day Outcomes
# 1. Objective 1
# 2. Objective 2
# 3. Objective 3

# %% [markdown]
# #

# %% [markdown]
# # Problem 1:
#
# ### Problem Statement:
#
# ### Constraints:
#
# #### Test cases:
# * test case 1
# * test case 2
# * test case 3
